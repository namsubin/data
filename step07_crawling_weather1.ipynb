# %% [markdown]
# * 네이버의 날씨 정보 가져오기

# %%
from bs4 import BeautifulSoup
from pprint import pprint
import requests

#pprint는 딕셔너리의 데이터가 긴 경우에 좀 더 보기 편하게 해준다

# %%
html = requests.get('https://search.naver.com/search.naver?query=날씨')
#pprint(html.text)

# %%
soup = BeautifulSoup(html.text, 'html.parser')
#파이썬에서 보기 좋게, 다루기 쉽게 파싱작업을 거쳐야 각 요소에 접근이 쉬워진다.

# %%
#soup 모듈의 find 함수를 사용해서 data1에 값을 저장한다.
#매개변수에는 div 태그명과 class 라는 속성의 값이 weather_box는 딕셔너리로 저장하는 
#코드이다. #find 함수를 사용할 때 주의할 점은 같은 웹페이지 소스코드에 같은 소스가 
#여러가지 있으면 맨 처음 탐색된것만 반환하고 나머지는 무시된다

data1 = soup.find('div', class_='weather_info')   # data1 = soup.find('div', {'class':'weather_info'})
#data1

# %%
from urllib.request import urlopen, Request
import urllib
import bs4

location = '용상동'
enc_location = urllib.parse.quote(location + '+날씨')

url = 'https://search.naver.com/search.naver?ie=utf8&query='+ enc_location

req = Request(url)
page = urlopen(req)
html = page.read()
soup = bs4.BeautifulSoup(html,'lxml')
temps=soup.find('div', class_='temperature_text').find('strong').get_text()
tm=temps[5:7]
cast = soup.find('div',"weather_main").get_text()

# 현재 용상동 기온은 13도 이고, 날씨는 흐림입니다
print("현재 " + location + " 기온은 " + tm + "℃입니다")
print("날씨는" + cast + "입니다")
# Out:
# 현재 용상동 기온은 11℃입니다
# 날씨는 맑음 입니다

# %%
# 현재 위치: 안동시 용상동
# 현재 용상동 기온은 15℃입니다
# 현재 미세먼지: 보통
# 현재 초미세먼지: 좋음
# 현재 강수확률: 30%


from urllib.request import urlopen, Request
import urllib
import bs4

location = '용상동'
enc_location = urllib.parse.quote(location + '+날씨')

url = 'https://search.naver.com/search.naver?ie=utf8&query='+ enc_location

req = Request(url)
html = urlopen(req).read()
soup = bs4.BeautifulSoup(html,'lxml')

temps=soup.find('div', class_='temperature_text').find('strong').get_text()
tm=temps[5:7]
cast = soup.find('div',"weather_main").get_text()

print("현재 위치:" , soup.find('h2', {'class': 'title'}).get_text())
print("현재 " + location + " 기온은 " + tm + "℃입니다")

# find_dust=soup.find('div', {'class': 'weather_info'}).find('li',class_='item_today level1').find('span').get_text()
# find_ultra_dust=soup.find('div', {'class': 'weather_info'}).find('li',class_='item_today level1').find('span').get_text()
# find_desc=dust=soup.find('div', {'class': 'weather_info'}).find('dd',class_='desc').get_text()

print(soup.find('ul',{'class':'today_chart_list'})[0]

# print('현재 미세먼지: '+find_dust)
# print('현재 초미세먼지: '+find_ultra_dust)
# print('현재 강수확률: '+find_desc)
# Out:
#   File "<ipython-input-3-245184774c1d>", line 36
#     # print('현재 강수확률: '+find_desc)
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
list=soup.find('ul',{'class':'today_chart_list'}).find('span').get_text()

print(list)
# Out:
# 보통

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('http://www.javavc.pe.kr')
response.encoding = 'utf-8'
html = response.text
#print(html)

soup = BeautifulSoup(html, 'html.parser') # 원하는 문자열로 잘라줌
#print(soup.prettify())                    # html문서 형식으로 출력

# %%
# url 코드를 파일로 저장
f = open('test.html', 'w', encoding='utf-8')
f.write(html)
f.close()

# %%
#!dir
html
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\n<head>\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta http-equiv="X-UA-Compatible" content="ie=edge">\n  <title>Document</title>\n  <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css">\n  <style>\n    h1{\n      margin: 2rem;\n    }\n    h1>span{\n      font-size: 1rem;\n    }\n    .main {\n      width: 70%;\n      margin: 3rem auto auto auto;\n      text-align: center\n    }\n\n    table {\n      width: 100%;\n    }\n  </style>\n</head>\n\n<body>\n  <h1>Web Crawling Test Site<span id="update">2021.7.19</span></h1>\n  <div class="main">\n    <h2 id="가나다전자">가나다 전자</h2>\n    <h3><span style="color: salmon">일별</span> 시세</h3>\n    <table class="table table-hover">\n      <tbody>\n        <tr>\n          <th scope="col">날짜</th>\n          <th scope="col">종가</th>\n          <th scope="col">전일비</th>\n          <th scope="col">시가</th>\n       
# ...

# %%
# url 파일에서 특정단어 찾기
s = html.split(' ') # 띄어쓰기 단위로 분할 # 앞뒤로 띄어쓰기 안되어 있으면 검색이 안됨
word = input('페이지에서 검색할 단어를 입력하세요 : ')
s.count(word)
# Out:
# 페이지에서 검색할 단어를 입력하세요 : id="가나다전자">가나다
# 1
