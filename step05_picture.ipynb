# %%
import numpy as np
from skimage import io
# from PIL import Image
# from cv2
import matplotlib.pyplot as plt

# %%
pic = io.imread('pic.jpg')

# %%
type(pic)
# Out:
# numpy.ndarray

# %%
pic.shape
# Out:
# (183, 275, 3)

# %%
pic
# Out:
# array([[[202, 224, 248],
#         [203, 225, 249],
#         [203, 225, 249],
#         ...,
#         [ 89, 154, 236],
#         [ 89, 154, 236],
#         [ 89, 154, 236]],
#
#        [[203, 225, 249],
#         [203, 225, 249],
#         [204, 226, 250],
#         ...,
#         [ 89, 154, 236],
#         [ 89, 154, 236],
#         [ 89, 154, 236]],
#
#        [[203, 225, 249],
#         [204, 226, 250],
#         [204, 226, 250],
#         ...,
#         [ 90, 155, 237],
#         [ 90, 155, 237],
#         [ 90, 155, 237]],
#
#        ...,
#
#        [[122, 135,  55],
#         [139, 152,  60],
#         [112, 127,  26],
#         ...,
#         [146, 110,  88],
#         [149, 113,  91],
#         [153, 117,  95]],
#
#        [[156, 170,  75],
#         [148, 164,  57],
#         [114, 131,  17],
#         ...,
#         [160, 119,  99],
#         [162, 121, 101],
#         [162, 121, 101]],
#
#        [[140, 153,  47],
#         [164, 179,  60],
#         [147, 163,  39],
#         ...,
#         [164, 123, 103],
#         [163, 122, 102],
#         [160, 119,  99]]], dtype=uint8)

# %%
np.min(pic), np.max(pic)
# Out:
# (0, 255)

# %%
plt.imshow(pic)

# %%
plt.imshow(pic[::-1])

# %%
# 회색으로 이미지 출력하기
from skimage import color

plt.imshow(color.rgb2gray(pic), cmap=plt.cm.gray)
