# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=[100,200,300]
y=[1,2,3]
plt.plot(x,y)

# %%
x=[100,200,300]
y=[1,2,3]
value=pd.Series([1,2,3],[100,200,300])
plt.plot(value)

# %%
x=[100,200,300]
y=[1,2,3]
plt.plot(x,y,':r')  # g(green), r(red), b(blue), -->, --<, --or

# %%
x=[100,200,300]
y=[1,2,3]
plt.plot(x,y,color='#ff00ff', linewidth='10')  # #ff00ff(핑크색), blue

# %%
x=[100,200,300]
y=[1,2,3]
plt.plot(x,y,'--r', linewidth='3')
plt.xlabel('X label',fontsize=16)
plt.ylabel('Y Label',fontsize=16)
plt.title('Matplotlib Test',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Matplotlib Test')

# %%
x=[100,200,300]
y=[1,2,3]
plt.plot(x,y,'--r', linewidth='3')
plt.xlabel('X label',fontsize=16)
plt.ylabel('Y Label',fontsize=16)
plt.title('Matplotlib Test',fontsize='20')
plt.savefig('sample.png')

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
y_=np.cos(x)

plt.plot(x,y)
plt.plot(x,y_, '-o')

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
y_=np.cos(x)

plt.plot(x,y, label='sin')
plt.plot(x,y_, '-o', label='cos')

plt.legend(loc=1)   # loc= 1,2,3,4

# %% [markdown]
# * scatter(산점도)

# %%
x=np.linspace(0,10,20)
y=x**2

plt.scatter(x,y, c='r', alpha=0.3)  # color or c
plt.show()

# %% [markdown]
# * histogram

# %%
x=[np.random.randint(1,7) for i in range(10000)]  # 10  100  10000

# %%
plt.hist(x, bins=11)
plt.show()

# %%
from random import *
lit=[]
for i in range(7):
    lit.append(randint(1,10000))
print(lit)
# Out:
# [7739, 1279, 2398, 3267, 635, 3527, 7387]

# %%
lit=[]
lit=[np.random.randint(1,7) for i in range(10000)] 
plt.hist(lit, bins=11)
plt.show()

# %%
labels=['one','two','three']
size=[100,20,10]

plt.pie(size, labels=labels)
plt.show()

# %% [markdown]
# * Bar Chart

# %%
plt.bar(['one','two','three'],[10,20,30])
plt.show()

# %%
plt.barh(['one','two','three'],[10,20,30])
plt.show()

# %% [markdown]
# * 선 색상과 스타일
# plt.plot(x,y,color='red'):red, green,blue
# plt.plot(x,y,color='r) : r,g,b,y,m(자홍),k(검정)등
# plt.plot(x,y,color='0.2'): 회색조(0-1사이 값)
# plt.plot(x,y,color='#ff0000'): 16진수 색상값
#
# plt.plot(x,y, linestyle='solid'): 실선(-)
# plt.plot(x,y, linestyle='dashed'): 대쉬선(--)
# plt.plot(x,y, linestyle='dashdot'): 대쉬도트선
# plt.plot(x,y, linestyle='dotted'): 점선
#
# plt.plot(x,y,'--r'): 빨간색 대쉬선
#
# '.': point maeker
# 'o': circle maeker(plt.plot(x,y,'o')
# '^': triangle_up malker
# 's': square marker
# 'p': pentagon marker
# '*': stat marker
# '+': plus marker
# 'x': x marker

# %%
# 공식문서:https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html
# 공식문서:https://matplotlib.org/3.2.1/api/pyplot_summary.html
